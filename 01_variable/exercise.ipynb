# %% [markdown]
# ### 변수 생성
# 변수명 = 자료

# %%
name = "capybara"
age = 100

print(name)
print(age)
# Out:
# capybara
# 100

# %%
score = 10
print(score)

score = 20
print(score)
# Out:
# 10
# 20

# %%
# int num = 1
# print(num)

# %%
x = 10
y = x + 5

print(x, y)
# Out:
# 10 15

# %%
team_name = "ohgiraffers"
my_team = team_name
print(my_team)
# Out:
# ohgiraffers

# %%
# print(age2) # 오류 발생
# name = 홍길동 # 오류
# print(Name) # 오류

# %%
height = 207.3

a = 171.8
abc = 180.2

# %%
team_name = "오지라퍼스"
print(team_name)


Team_name = "ohgiraffers"
print(team_name)
print(Team_name)
# Out:
# 오지라퍼스
# 오지라퍼스
# ohgiraffers

# %%
#스네이크 케이스
team_name = "오지라퍼스"
print(team_name)

#카멜 케이스
teamName = "오지라퍼스"
print(teamName)
# Out:
# 오지라퍼스
# 오지라퍼스

# %%
우리팀 = "오지라퍼스" #가능하지만 인코딩 등 문제 야기 할 수있으며 사용을 지양

# %%
#영문과 숫자를 혼합 작성 가능, 숫자를 가장 앞에 작성 x
# (숫자로만 구성하는 것도 불가능)

team_1_name = "오지라퍼스"
# 1_team_name = "오지라퍼스"
# 20240101 = "오지라퍼스"

print(team_1_name)
# print(1_team_name)
# print(20240101)
# Out:
# 오지라퍼스

# %%
# 언더바를 제외한 특수 문자는 사용 불가능하다
# team_@_name = "오지라퍼스" #syntax error
# 파이썬 예약어(if,for,while,else) 사용 x

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
10
# Out:
# 10

# %%
print(_)
print(_*3)
# Out:
# [2, 3, 4]
# [2, 3, 4, 2, 3, 4, 2, 3, 4]

# %%
x, _ , z = (1, 2, 3)
print(x)
print(z)
# Out:
# 1
# 3

# %%
x, *_, y = (1, 2, 3, 4, 5)
print(x)
print(y)
# Out:
# 1
# 5

# %%
_internal_name = 'one_module'
_internal_version = '1.0'

# %%
million = 1_000_000
print(million)
# Out:
# 1000000

# %%
for_value = 'for blah'
print(for_value)
# Out:
# for blah

# %% [markdown]
# _ -> 내부용 또는 값 무시
#
# __ -> private 용도(외부접근 차단)
#
#
# __name__ -> 파이썬이 정의한 특수 메서드(매직 메서드)
